# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from pathlib import Path

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
csv_file = Path("output_data/cities.csv")
city_data_df = pd.read_csv(csv_file)

# Display sample data
city_data_df.head()
# Out:
#    City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0     ostrovnoy  68.0531   39.5131      1.21        92           9
# 1        1         bumba   2.1833   22.4667     34.03        40         100
# 2        2       methoni  36.8197   21.7049     19.56        66           9
# 3        3  punta arenas -53.1500  -70.9167      7.06        81           0
# 4        4    quang ngai  15.1167  108.8000     24.23        89         100
#
#    Wind Speed Country        Date
# 0        3.24      RU  1681822234
# 1        0.61      CD  1681822682
# 2        4.18      GR  1681822683
# 3       11.32      CL  1681822134
# 4        2.48      VN  1681822685

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
city_plot = city_data_df.hvplot.points (
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    size = "Humidity",
    color = "City"
)

# Display the map
city_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
idea_city_data = city_data_df.loc[(city_data_df["Max Temp"] <= 30) & (city_data_df["Max Temp"] > 21) & (city_data_df["Wind Speed"] < 6) & (city_data_df["Cloudiness"] < 20),:]

# Drop any rows with null values
drop_city_data_df = idea_city_data.dropna(how="any")

# Display sample data
drop_city_data_df
# Out:
#      City_ID             City      Lat       Lng  Max Temp  Humidity  \
# 7          7      port alfred -33.5906   26.8910     25.10        76
# 26        26       bredasdorp -34.5322   20.0403     25.25        31
# 43        43        cape town -33.9258   18.4232     25.62        56
# 46        46  arraial do cabo -22.9661  -42.0278     28.92        65
# 54        54       vila velha -20.3297  -40.2925     28.30        75
# 58        58         karratha -20.7377  116.8463     26.14        53
# 75        75           iztapa  13.9333  -90.7075     27.27        62
# 85        85         hermanus -34.4187   19.2345     23.22        59
# 90        90         celestun  20.8667  -90.4000     21.12        76
# 110      110         sigiriya   7.9518   80.7426     28.44        63
# 125      125          zhangye  38.9342  100.4517     24.36        14
# 133      133             faya  18.3851   42.4509     24.06        34
# 194      194      mundo nuevo  18.7000  -95.5000     23.43        83
# 210      210     jan kempdorp -27.9225   24.8305     27.81        13
# 216      216            erzin  36.9559   36.2000     25.94        42
# 224      224            cabra  37.4725   -4.4421     25.04        22
# 229      229          kavieng  -2.5744  150.7967     28.56        70
# 245      245     duiwelskloof -23.6934   30.1400     27.83        24
# 255      255     kruisfontein -34.0033   24.7314     22.71        47
# 268      268            sabha  27.0377   14.4283     29.41        19
# 274      274          bontang   0.1333  117.5000     27.65        81
# 283      283         kirakira -10.4544  161.9205     25.36        83
# 296      296          maunabo  18.0072  -65.8993     28.16        83
# 311      311         jinchang  38.4953  102.1739     22.79        16
# 314      314        guarapari -20.6667  -40.4975     28.83        58
# 329      329            bowen -20.0167  148.2333     23.44        83
# 355      355           davila  18.4726  120.5763     28.99        78
# 379      379          sambava -14.2667   50.1667     26.75        85
# 381      381            buala  -8.1450  159.5921     25.87        75
# 406      406             tura  25.5198   90.2201     29.33        28
# 421      421            yanam  16.7333   82.2167     29.26        60
# 447      447           sirnak  37.5228   42.4594     21.04        30
# 451      451             trat  12.5000  102.5000     27.75        80
# 455      455            yulin  22.6333  110.1500     25.91        89
# 486      486         acajutla  13.5928  -89.8275     27.41        57
# 498      498       rio branco  -9.9747  -67.8100     24.34        94
# 500      500           mangan  27.5167   88.5333     24.12        45
# 521      521        viradouro -20.8731  -48.2969     25.33        78
# 538      538           yaring   6.8662  101.3689     29.30        76
# 550      550         umm lajj  25.0213   37.2685     28.17        47
#
#      Cloudiness  Wind Speed Country        Date
# 7             0        0.89      ZA  1681822169
# 26            0        2.63      ZA  1681822135
# 43            0        5.14      ZA  1681821903
# 46            0        2.57      BR  1681822188
# 54            0        4.63      BR  1681822092
# 58            5        2.31      AU  1681822714
# 75           10        1.49      GT  1681822724
# 85            0        3.30      ZA  1681822254
# 90            0        4.94      MX  1681822734
# 110           6        4.51      LK  1681822656
# 125          17        4.78      CN  1681822755
# 133           4        4.56      SA  1681822759
# 194           0        2.67      MX  1681822796
# 210           0        0.91      ZA  1681822817
# 216           0        2.82      TR  1681822370
# 224           9        2.72      ES  1681822856
# 229          17        2.46      PG  1681822859
# 245           0        3.46      ZA  1681822873
# 255           0        4.15      ZA  1681822328
# 268           6        5.76      LY  1681822368
# 274          10        1.65      ID  1681822895
# 283          18        0.55      SB  1681822902
# 296          11        3.26      PR  1681822910
# 311           4        4.66      CN  1681822920
# 314           7        2.55      BR  1681822908
# 329          16        5.17      AU  1681822933
# 355           0        1.51      PH  1681822950
# 379           4        5.61      MG  1681822969
# 381          14        1.62      SB  1681822971
# 406           0        1.56      IN  1681822993
# 421           0        3.55      IN  1681823002
# 447           8        3.22      TR  1681823019
# 451           4        1.77      TH  1681823022
# 455           2        4.36      CN  1681823024
# 486          15        1.82      SV  1681822859
# 498           0        0.00      BR  1681822815
# 500          12        0.41      IN  1681823053
# 521           8        4.18      BR  1681823068
# 538          17        3.79      TH  1681823081
# 550           0        4.23      SA  1681822918

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = drop_city_data_df.copy()
hotel_df = hotel_df[["City","Country","Lat","Lng","Humidity"]]

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"]=""

# Display sample data
hotel_df
# Out:
#                 City Country      Lat       Lng  Humidity Hotel Name
# 7        port alfred      ZA -33.5906   26.8910        76
# 26        bredasdorp      ZA -34.5322   20.0403        31
# 43         cape town      ZA -33.9258   18.4232        56
# 46   arraial do cabo      BR -22.9661  -42.0278        65
# 54        vila velha      BR -20.3297  -40.2925        75
# 58          karratha      AU -20.7377  116.8463        53
# 75            iztapa      GT  13.9333  -90.7075        62
# 85          hermanus      ZA -34.4187   19.2345        59
# 90          celestun      MX  20.8667  -90.4000        76
# 110         sigiriya      LK   7.9518   80.7426        63
# 125          zhangye      CN  38.9342  100.4517        14
# 133             faya      SA  18.3851   42.4509        34
# 194      mundo nuevo      MX  18.7000  -95.5000        83
# 210     jan kempdorp      ZA -27.9225   24.8305        13
# 216            erzin      TR  36.9559   36.2000        42
# 224            cabra      ES  37.4725   -4.4421        22
# 229          kavieng      PG  -2.5744  150.7967        70
# 245     duiwelskloof      ZA -23.6934   30.1400        24
# 255     kruisfontein      ZA -34.0033   24.7314        47
# 268            sabha      LY  27.0377   14.4283        19
# 274          bontang      ID   0.1333  117.5000        81
# 283         kirakira      SB -10.4544  161.9205        83
# 296          maunabo      PR  18.0072  -65.8993        83
# 311         jinchang      CN  38.4953  102.1739        16
# 314        guarapari      BR -20.6667  -40.4975        58
# 329            bowen      AU -20.0167  148.2333        83
# 355           davila      PH  18.4726  120.5763        78
# 379          sambava      MG -14.2667   50.1667        85
# 381            buala      SB  -8.1450  159.5921        75
# 406             tura      IN  25.5198   90.2201        28
# 421            yanam      IN  16.7333   82.2167        60
# 447           sirnak      TR  37.5228   42.4594        30
# 451             trat      TH  12.5000  102.5000        80
# 455            yulin      CN  22.6333  110.1500        89
# 486         acajutla      SV  13.5928  -89.8275        57
# 498       rio branco      BR  -9.9747  -67.8100        94
# 500           mangan      IN  27.5167   88.5333        45
# 521        viradouro      BR -20.8731  -48.2969        78
# 538           yaring      TH   6.8662  101.3689        76
# 550         umm lajj      SA  25.0213   37.2685        47

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000

params = {
    "apiKey":geoapify_key,
    "categories":"accommodation.hotel",
    "format":"json"
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    
    # get latitude, longitude from the DataFrame
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    name_address = name_address.json()

    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# port alfred - nearest hotel: No hotel found
# bredasdorp - nearest hotel: Victoria Hotel
# cape town - nearest hotel: Townhouse Hotel
# arraial do cabo - nearest hotel: No hotel found
# vila velha - nearest hotel: Hotel Prainha
# karratha - nearest hotel: Karratha International Hotel
# iztapa - nearest hotel: Hotel Solyplaya
# hermanus - nearest hotel: Aloe guest house
# celestun - nearest hotel: Hotel Flamingo Playa
# sigiriya - nearest hotel: Jetwing Vil Uyana
# zhangye - nearest hotel: Zhangye Hotel 张掖饭店
# faya - nearest hotel: No hotel found
# mundo nuevo - nearest hotel: No hotel found
# jan kempdorp - nearest hotel: Jan Kemp Hotel
# erzin - nearest hotel: No hotel found
# cabra - nearest hotel: Pensión Guerrero
# kavieng - nearest hotel: Kavieng Hotel
# duiwelskloof - nearest hotel: No hotel found
# kruisfontein - nearest hotel: No hotel found
# sabha - nearest hotel: فندق الكاظم-سبها
# bontang - nearest hotel: Hotel Sederhana
# kirakira - nearest hotel: No hotel found
# maunabo - nearest hotel: No hotel found
# jinchang - nearest hotel: No hotel found
# guarapari - nearest hotel: Osmar Hotel
# bowen - nearest hotel: Whitsunday Sands Resort
# davila - nearest hotel: Blue Ridge Beach Resort
# sambava - nearest hotel: Royal Sava Hôtel
# buala - nearest hotel: No hotel found
# tura - nearest hotel: No hotel found
# yanam - nearest hotel: No hotel found
# sirnak - nearest hotel: Hotel Menekse
# trat - nearest hotel: No hotel found
# yulin - nearest hotel: No hotel found
# acajutla - nearest hotel: Hotel Lara
# rio branco - nearest hotel: No hotel found
# mangan - nearest hotel: No hotel found
# viradouro - nearest hotel: No hotel found
# yaring - nearest hotel: No hotel found
# umm lajj - nearest hotel: No hotel found
#                 City Country      Lat       Lng  Humidity  \
# 7        port alfred      ZA -33.5906   26.8910        76
# 26        bredasdorp      ZA -34.5322   20.0403        31
# 43         cape town      ZA -33.9258   18.4232        56
# 46   arraial do cabo      BR -22.9661  -42.0278        65
# 54        vila velha      BR -20.3297  -40.2925        75
# 58          karratha      AU -20.7377  116.8463        53
# 75            iztapa      GT  13.9333  -90.7075        62
# 85          hermanus      ZA -34.4187   19.2345        59
# 90          celestun      MX  20.8667  -90.4000        76
# 110         sigiriya      LK   7.9518   80.7426        63
# 125          zhangye      CN  38.9342  100.4517        14
# 133             faya      SA  18.3851   42.4509        34
# 194      mundo nuevo      MX  18.7000  -95.5000        83
# 210     jan kempdorp      ZA -27.9225   24.8305        13
# 216            erzin      TR  36.9559   36.2000        42
# 224            cabra      ES  37.4725   -4.4421        22
# 229          kavieng      PG  -2.5744  150.7967        70
# 245     duiwelskloof      ZA -23.6934   30.1400        24
# 255     kruisfontein      ZA -34.0033   24.7314        47
# 268            sabha      LY  27.0377   14.4283        19
# 274          bontang      ID   0.1333  117.5000        81
# 283         kirakira      SB -10.4544  161.9205        83
# 296          maunabo      PR  18.0072  -65.8993        83
# 311         jinchang      CN  38.4953  102.1739        16
# 314        guarapari      BR -20.6667  -40.4975        58
# 329            bowen      AU -20.0167  148.2333        83
# 355           davila      PH  18.4726  120.5763        78
# 379          sambava      MG -14.2667   50.1667        85
# 381            buala      SB  -8.1450  159.5921        75
# 406             tura      IN  25.5198   90.2201        28
# 421            yanam      IN  16.7333   82.2167        60
# 447           sirnak      TR  37.5228   42.4594        30
# 451             trat      TH  12.5000  102.5000        80
# 455            yulin      CN  22.6333  110.1500        89
# 486         acajutla      SV  13.5928  -89.8275        57
# 498       rio branco      BR  -9.9747  -67.8100        94
# 500           mangan      IN  27.5167   88.5333        45
# 521        viradouro      BR -20.8731  -48.2969        78
# 538           yaring      TH   6.8662  101.3689        76
# 550         umm lajj      SA  25.0213   37.2685        47
#
#                        Hotel Name
# 7                  No hotel found
# 26                 Victoria Hotel
# 43                Townhouse Hotel
# 46                 No hotel found
# 54                  Hotel Prainha
# 58   Karratha International Hotel
# 75                Hotel Solyplaya
# 85               Aloe guest house
# 90           Hotel Flamingo Playa
# 110             Jetwing Vil Uyana
# 125            Zhangye Hotel 张掖饭店
# 133                No hotel found
# 194                No hotel found
# 210                Jan Kemp Hotel
# 216                No hotel found
# 224              Pensión Guerrero
# 229                 Kavieng Hotel
# 245                No hotel found
# 255                No hotel found
# 268              فندق الكاظم-سبها
# 274               Hotel Sederhana
# 283                No hotel found
# 296                No hotel found
# 311                No hotel found
# 314                   Osmar Hotel
# 329       Whitsunday Sands Resort
# 355       Blue Ridge Beach Resort
# 379              Royal Sava Hôtel
# 381                No hotel found
# 406                No hotel found
# 421                No hotel found
# 447                 Hotel Menekse
# 451                No hotel found
# 455                No hotel found
# 486                    Hotel Lara
# 498                No hotel found
# 500                No hotel found
# 521                No hotel found
# 538                No hotel found
# 550                No hotel found

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    scale = 0.5,
    color = "City"
    #hover_cols = ["Country", "Hotel Name"]
)

# Display the map
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City)
